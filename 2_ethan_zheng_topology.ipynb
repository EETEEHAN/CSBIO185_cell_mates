# %% [markdown]
# # Part 2 — Ethan Zheng: Topological analysis

# %% [markdown]
# Rebuild the lookup and graph from Notebook 1 (or import its functions)

# %% [markdown]
# ## Steepest-ascent basin assignment

# %% [markdown]
# Memoized walk from each node to the peak it terminates at

# %% [markdown]
# Group nodes by terminal peak; report basin sizes

# %% [markdown]
# ## Ranked refuge table

# %% [markdown]
# Sort peaks by basin size; tabulate top 20 with their drug composition

# %% [markdown]
# ## Hand off to Notebook 3

# %% [markdown]
# Store the basins dict in memory or pickle it for downstream notebooks
